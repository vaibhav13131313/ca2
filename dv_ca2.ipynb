# %% [markdown]
# <a href="https://colab.research.google.com/github/vaibhav13131313/ca2/blob/main/dv_ca2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/archive.zip')
df
# Out:
#       long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0             1               11.8                 6.1          1          0
# 1             0               14.0                 5.4          0          0
# 2             0               11.8                 6.3          1          1
# 3             0               14.4                 6.1          0          1
# 4             1               13.5                 5.9          0          0
# ...         ...                ...                 ...        ...        ...
# 4996          1               13.6                 5.1          0          0
# 4997          1               11.9                 5.4          0          0
# 4998          1               12.9                 5.7          0          0
# 4999          1               13.2                 6.2          0          0
# 5000          1               15.4                 5.4          1          1
#
# ...

# %%
df.isnull().sum()
# Out:
# long_hair                    0
# forehead_width_cm            0
# forehead_height_cm           0
# nose_wide                    0
# nose_long                    0
# lips_thin                    0
# distance_nose_to_lip_long    0
# gender                       0
# dtype: int64

# %%
df.head()
# Out:
#    long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0          1               11.8                 6.1          1          0
# 1          0               14.0                 5.4          0          0
# 2          0               11.8                 6.3          1          1
# 3          0               14.4                 6.1          0          1
# 4          1               13.5                 5.9          0          0
#
#    lips_thin  distance_nose_to_lip_long  gender
# 0          1                          1    Male
# 1          1                          0  Female
# 2          1                          1    Male
# 3          1                          1    Male
# 4          0                          0  Female

# %%
df.tail()
# Out:
#       long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 4996          1               13.6                 5.1          0          0
# 4997          1               11.9                 5.4          0          0
# 4998          1               12.9                 5.7          0          0
# 4999          1               13.2                 6.2          0          0
# 5000          1               15.4                 5.4          1          1
#
#       lips_thin  distance_nose_to_lip_long  gender
# 4996          0                          0  Female
# 4997          0                          0  Female
# 4998          0                          0  Female
# 4999          0                          0  Female
# 5000          1                          1    Male

# %%
df.describe()
# Out:
#          long_hair  forehead_width_cm  forehead_height_cm    nose_wide  \
# count  5001.000000        5001.000000         5001.000000  5001.000000
# mean      0.869626          13.181484            5.946311     0.493901
# std       0.336748           1.107128            0.541268     0.500013
# min       0.000000          11.400000            5.100000     0.000000
# 25%       1.000000          12.200000            5.500000     0.000000
# 50%       1.000000          13.100000            5.900000     0.000000
# 75%       1.000000          14.000000            6.400000     1.000000
# max       1.000000          15.500000            7.100000     1.000000
#
#          nose_long    lips_thin  distance_nose_to_lip_long
# count  5001.000000  5001.000000                5001.000000
# mean      0.507898     0.493101                   0.498900
# std       0.499988     0.500002                   0.500049
# min       0.000000     0.000000                   0.000000
# ...

# %%
df.isnull().sum()
# Out:
# long_hair                    0
# forehead_width_cm            0
# forehead_height_cm           0
# nose_wide                    0
# nose_long                    0
# lips_thin                    0
# distance_nose_to_lip_long    0
# gender                       0
# dtype: int64

# %%
df.shape
# Out:
# (5001, 8)

# %%
df.columns
# Out:
# Index(['long_hair', 'forehead_width_cm', 'forehead_height_cm', 'nose_wide',
#        'nose_long', 'lips_thin', 'distance_nose_to_lip_long', 'gender'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5001 entries, 0 to 5000
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   long_hair                  5001 non-null   int64
#  1   forehead_width_cm          5001 non-null   float64
#  2   forehead_height_cm         5001 non-null   float64
#  3   nose_wide                  5001 non-null   int64
#  4   nose_long                  5001 non-null   int64
#  5   lips_thin                  5001 non-null   int64
#  6   distance_nose_to_lip_long  5001 non-null   int64
#  7   gender                     5001 non-null   object
# dtypes: float64(2), int64(5), object(1)
# memory usage: 312.7+ KB

# %%
df['long_hair'].value_counts()
# Out:
# 1    4349
# 0     652
# Name: long_hair, dtype: int64

# %%
df['gender'].value_counts()
# Out:
# Female    2501
# Male      2500
# Name: gender, dtype: int64

# %%
df['forehead_width_cm'].unique()
# Out:
# array([11.8, 14. , 14.4, 13.5, 13. , 15.3, 11.9, 12.1, 12.5, 15.5, 14.7,
#        14.5, 14.2, 15.2, 14.6, 12.8, 12.9, 12.2, 12.3, 12.7, 14.1, 11.5,
#        13.8, 13.7, 12. , 11.4, 15.4, 13.3, 13.2, 14.3, 13.9, 11.7, 15.1,
#        15. , 12.4, 11.6, 12.6, 14.8, 13.1, 13.4, 13.6, 14.9])

# %%
df['forehead_height_cm'].unique()
# Out:
# array([6.1, 5.4, 6.3, 5.9, 6.8, 6.2, 5.2, 5.8, 6.7, 6.5, 6. , 5.6, 7. ,
#        6.4, 5.3, 5.7, 5.1, 5.5, 7.1, 6.6, 6.9])

# %%
df.groupby('long_hair').mean()
# Out:
# <ipython-input-19-b64f9d8cac39>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('long_hair').mean()
#            forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# long_hair
# 0                  13.200153            5.970399   0.492331   0.489264
# 1                  13.178685            5.942699   0.494137   0.510692
#
#            lips_thin  distance_nose_to_lip_long
# long_hair
# 0           0.478528                   0.532209
# 1           0.495286                   0.493907

# %%
nos=df['nose_long'].value_counts().reset_index()
nos
# Out:
#    index  nose_long
# 0      1       2540
# 1      0       2461

# %%
sns.set_style("darkgrid")
colors = sns.color_palette("pastel")
plt.figure(figsize=(10, 6))
sns.barplot(x='index', y='nose_long', data=nos, palette=colors)
plt.xlabel('nose_long', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.title('nose_long Level Distribution', fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.tight_layout()
plt.show()

# %%
long_hair=df['long_hair'].value_counts().reset_index()
long_hair
# Out:
#    index  long_hair
# 0      1       4349
# 1      0        652

# %%
plt.figure(figsize=(12, 8))
ax = sns.barplot(x='index', y='long_hair', data=long_hair, palette='viridis')
plt.xlabel('long_hair', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.title('long_hair Distribution', fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(fontsize=10)
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')
plt.tight_layout()
plt.show()

# %%
t=df['forehead_width_cm'].value_counts().reset_index()
t
# Out:
#     index  forehead_width_cm
# 0    12.0                168
# 1    11.8                161
# 2    14.1                155
# 3    14.0                154
# 4    11.5                154
# 5    11.6                152
# 6    11.9                150
# 7    13.3                149
# 8    14.2                149
# 9    12.2                145
# 10   12.6                145
# 11   12.1                145
# 12   13.2                143
# 13   14.3                143
# 14   12.9                141
# 15   12.5                141
# 16   13.7                140
# 17   12.8                138
# 18   12.3                138
# 19   13.6                138
# 20   13.0                137
# 21   13.4                137
# 22   13.5                136
# 23   13.8                134
# 24   11.7                133
# 25   13.1                131
# 26   13.9                131
# 27   12.7                130
# 28   12.4                127
# 29   11.4                 84
# 30   14.9                 79
# ...

# %%
plt.figure(figsize=(18, 10))
sns.barplot(x='index', y='forehead_width_cm', data=t)
plt.xlabel('forehead_width_cm')
plt.ylabel('Index')
plt.title('forehead_width_cm Distribution')
plt.show()

# %%
tier=df['forehead_height_cm'].value_counts().reset_index()
tier
# Out:
#     index  forehead_height_cm
# 0     5.7                 306
# 1     5.9                 303
# 2     5.3                 301
# 3     5.5                 299
# 4     6.1                 296
# 5     5.1                 293
# 6     6.2                 290
# 7     5.8                 290
# 8     6.4                 287
# 9     6.3                 285
# 10    6.5                 285
# 11    5.6                 279
# 12    6.0                 275
# 13    5.4                 265
# 14    5.2                 259
# 15    6.6                 126
# 16    6.8                 118
# 17    7.0                 117
# 18    7.1                 113
# 19    6.9                 109
# 20    6.7                 105

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='index', y='forehead_height_cm', data=tier)
plt.xlabel('forehead_height_cm')
plt.ylabel('Count')
plt.title('forehead_height_cm Tier Distribution')
plt.show()

# %%
nose_wide=df['nose_wide'].value_counts().reset_index()
nose_wide=nose_wide.sort_values(by='nose_wide')
nose_wide
# Out:
#    index  nose_wide
# 1      1       2470
# 0      0       2531

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='index', y='nose_wide', data=nose_wide)
plt.xlabel('nose_wide')
plt.ylabel('Count')
plt.title('nose_wide Distribution')
plt.show()

# %%
nose_long=df['nose_long'].value_counts().reset_index()
nose_long
# Out:
#    index  nose_long
# 0      1       2540
# 1      0       2461

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x='index', y='nose_long', data=nose_long)
plt.xlabel('nose_long')
plt.ylabel('Count')
plt.title('nose_long Distribution')
plt.show()

# %%
lips_thin_counts = df['lips_thin'].value_counts()
# Plot a pie chart
plt.figure(figsize=(8, 8))
plt.pie(lips_thin_counts, labels=lips_thin_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of lips_thin')
plt.axis('equal') # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
long_hair_counts = df['long_hair'].value_counts()
# Plot a pie chart for City
plt.figure(figsize=(8, 8))
color=['#706EEB','#5756B7','#B7B9EE']
plt.pie(long_hair_counts, labels=long_hair_counts.index, autopct='%1.1f%%', startangle=140,colors=color)
plt.title('Distribution of long_hair')
plt.axis('equal')
plt.show()

# %%
cross_tab = pd.crosstab(df['forehead_width_cm'], df['forehead_height_cm'])
custom_colors = ["#D891EE", "#C649EB", "#9A39B8"]
plt.figure(figsize=(40, 10))
cross_tab.plot(kind='bar', stacked=True, color=custom_colors)
plt.xlabel('forehead_width_cm')
plt.ylabel('Count')
plt.title('Distribution of forehead_height_cm by forehead_width_cm')
plt.xticks(rotation=65)
plt.legend(title='forehead_height_cm', bbox_to_anchor=(1.00005, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
plt.scatter(df['forehead_width_cm'], df['forehead_height_cm'])
plt.xlabel('forehead_width_cm')
plt.ylabel('forehead_height_cm')
plt.title('Scatter Plot of forehead_width_cm vs forehead_height_cm')
plt.show()

# %%
cross_tab_city_leave = pd.crosstab(df['nose_wide'], df['nose_long'])
plt.figure(figsize=(10, 6))
cross_tab_city_leave.plot(kind='bar', stacked=True, colormap='coolwarm')
plt.xlabel('nose_wide')
plt.ylabel('Count')
plt.title('Distribution of nose_wide by nose_wide')
plt.xticks(rotation=45)
plt.legend(title='nose_wide', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
numerical_columns = ['nose_wide', 'nose_long', 'lips_thin']
numerical_data = df[numerical_columns]
correlation_matrix = numerical_data.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
sns.pairplot(df[['distance_nose_to_lip_long', 'long_hair','lips_thin']])
plt.suptitle('Pair Plot of Numerical Variables', y=1.02)
plt.show()

# %%
attributes = [ 'forehead_width_cm', 'forehead_height_cm']
for attribute in attributes:
    plt.figure(figsize=(8, 6))
    sns.boxplot(x='gender', y=attribute, data=df)
    plt.title(f'Box Plot of {attribute} by Gender')
    plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='nose_wide', hue='forehead_height_cm', data=df, palette='Set2', dodge=True)
plt.title('Distribution ofnose wide by nose long')
plt.xlabel('nose_long')
plt.ylabel('Count')
plt.legend(title='Nose', loc='upper right')
plt.show()
